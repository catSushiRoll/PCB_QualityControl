# %% [markdown]
# <a href="https://colab.research.google.com/github/catSushiRoll/PCB_QualityControl/blob/main/%5BKP%5D_Train_QC_PCB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training Dataset for QC

# %% [markdown]
# ##Load Dataset from google drive
# Optional, if the dataset is from roboflow in download code form, no need to mount from drive. After running the Load Dataset, we'll have temporary file, zip it to g-drive due to time efficiency

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## CUSTOM TRAIN!!!

# %% [markdown]
# ### Install Yolov8

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 917, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {list(MODES)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=checks'. Valid modes are ['benchmark', 'track', 'predict', 'val', 'train', 'export'].
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
# ...

# %% [markdown]
# ###Load Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LSijSwwxAImb6GDMuSZO")
project = rf.workspace("kerjakerjakerja-wuecn").project("compdetect-eg2gv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 76.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 110.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to CompDetect-1 in yolov8:: 100%|██████████| 3210/3210 [00:00<00:00, 3930.86it/s]

# %%
# !zip -r /content/drive/MyDrive/dataset_KP.zip /content/CompDetect-1
# Out:
#   adding: content/CompDetect-1/ (stored 0%)
#   adding: content/CompDetect-1/README.dataset.txt (deflated 12%)
#   adding: content/CompDetect-1/train/ (stored 0%)
#   adding: content/CompDetect-1/train/labels/ (stored 0%)
#   adding: content/CompDetect-1/train/labels/inductor14_jpg.rf.4dd471f2b0c51a887ee928fba5487de5.txt (deflated 29%)
#   adding: content/CompDetect-1/train/labels/PCBA_592_jpg.rf.073256fa7869aaca6fb2d02f939c913b.txt (deflated 56%)
#   adding: content/CompDetect-1/train/labels/PCBA_13_jpg.rf.03653d5fab44b287f4e9cd9297cfa448.txt (deflated 64%)
#   adding: content/CompDetect-1/train/labels/PCBA_161_jpg.rf.bc5d628de39bab9f7548064fa2f5ecad.txt (deflated 53%)
#   adding: content/CompDetect-1/train/labels/PCBA_3_jpg.rf.06982dd6a8cbe14a7cd216f61205c4c1.txt (deflated 55%)
#   adding: content/CompDetect-1/train/labels/PCBA_552_jpg.rf.dc095a5f66fbaf800c5c26fd3d6f2bf1.txt (deflated 68%)
# ...

# %% [markdown]
# ###Train

# %%
#EDIT THIS SYNTAX BEFORE RUNNING IT!!!!
# !yolo task=detect mode=train model=yolov8n.pt data='/content/CompDetect-1/data.yaml' epochs=100
# Out:
# ...
# Ultralytics 8.3.249 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r /content/drive/MyDrive/runs_dataset_KP2.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch8190.jpg (deflated 7%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 3%)
#   adding: content/runs/detect/train/labels.jpg (deflated 25%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 11%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 12%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 11%)
#   adding: content/runs/detect/train/BoxP_curve.png (deflated 4%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train/args.yaml (deflated 53%)
# ...
